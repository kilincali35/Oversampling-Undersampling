# %%
import numpy as np
import pandas as pd


df = pd.read_csv(r'C:\Users\ali.kilinc\Desktop\NEW DATA\INPUT\N34_PYTHON_INPUT.csv', index_col= False)
df = df.drop(df.columns[[0]], axis=1)
df = df.replace('?', np.NaN)

#print(df.columns)
#print(df.info())
#print(df.head(10))

df = pd.DataFrame(df)

X = df.iloc[:, :-1].values
xcol = df.columns[:-1]
Y = df.iloc[:, 59:].values
ycol = df.columns[59:]

df_x = pd.DataFrame(X, columns = xcol)
df_y = pd.DataFrame(Y, columns = ycol)

for col in ['SERVICE_GROUP_CODE', 'SERVICE_TYPE_CODE', 'FULL_TRUCK_TYPE','SYSTEM_FULL_TRUCK_TYPE',
        'DT_RDY_WEEK', 'DT_RDY_DAY', 'CUSTOMER_COMPANY_CODE','LOADING_COMPANY_CODE',
       'CUSTOMS_COMPANY_CODE', 'CUSTOMSEE_COMPANY_CODE','DELIVERY_COMPANY_CODE', 'CUSTOMS_TYPE', 'CARRY_TYPE', 'SPECIAL_LOAD_TYPE','FORBIDDEN_MODE',
       'GATE_COMPANY_CODE','LOADING_COUNTRY', 'DELIVERY_COUNTRY', 'DT_ETA_WEEK','DT_ETA_DAY']:
    df_x[col] = df_x[col].astype('object')

for col in ['PW', 'WH_DELIVERED', 'GROSS_WEIGHT', 'FREEZONE', 'REVENUE']:
    df_x[col] = df_x[col].astype('int')
    
df_x.info()
df_x.dtypes
df_x.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 59 columns):
# RUN_ID                     0 non-null object
# ACTIVE                     0 non-null object
# ORGANIZATION_CODE          0 non-null object
# SERVICE_GROUP_CODE         21 non-null object
# ORDER_STATE                0 non-null object
# SERVICE_TYPE_CODE          21 non-null object
# PW                         21 non-null int32
# FULL_TRUCK_TYPE            21 non-null object
# RELATED_ORDER_CODE         0 non-null object
# RELATED_ORDER_TYPE         0 non-null object
# DATE_BOOKING               0 non-null object
# DATE_LOADING               0 non-null object
# WH_DELIVERED               21 non-null int32
# DATE_WH_ENTRY              0 non-null object
# LAST_WH                    0 non-null object
# DATE_LAST_WH_FINISH        0 non-null object
# CUSTOMER_COMPANY_CODE      21 non-null object
# LOADING_COMPANY_CODE       21 non-null object
# CUSTOMS_COMPANY_CODE       21 non-null object
# CUSTOMSEE_COMPANY_CODE     0 non-null object
# DELIVERY_COMPANY_CODE      21 non-null object
# CUSTOMS_TYPE               21 non-null object
# POSITION_CODE              0 non-null object
# POSITION_STATE             0 non-null object
# RORO_LOAD_CODE             0 non-null object
# TRAIN_LOAD_CODE            0 non-null object
# PLATE_NUMBER               0 non-null object
# FREEZONE                   21 non-null int32
# CARRY_TYPE                 21 non-null object
# CARRY_RESTRICTION          0 non-null object
# OG_DELAY                   0 non-null object
# PREFERRED_MODE             0 non-null object
# LAST_WH_COMPANY_CODE       0 non-null object
# SPECIAL_LOAD_TYPE          0 non-null object
# GATE_COMPANY_CODE          0 non-null object
# GROSS_WEIGHT               21 non-null int32
# SYSTEM_FULL_TRUCK_TYPE     21 non-null object
# DEPOT_COMPANY_CODE         0 non-null object
# PREFERRED_MULT             0 non-null object
# POS_VH_CATEGORY            0 non-null object
# DISPOSITION_CODE           0 non-null object
# FROM_COMPANY_CODE          0 non-null object
# TO_COMPANY_CODE            0 non-null object
# DATE_PORT_ARRIVAL          0 non-null object
# REPLAN                     0 non-null object
# PRIO_COEF                  0 non-null object
# LATENESS_EXCEPTION         0 non-null object
# FORBIDDEN_MODE             0 non-null object
# ESTIMATED_LOADING_START    0 non-null object
# IGNORE_DEPOT               0 non-null object
# UNLOADING_COMPANY_CODE     0 non-null object
# POSITION_UNLOADING_NO      0 non-null object
# REVENUE                    21 non-null int32
# DT_RDY_WEEK                21 non-null object
# DT_RDY_DAY                 21 non-null object
# DT_ETA_WEEK                21 non-null object
# DT_ETA_DAY                 21 non-null object
# LOADING_COUNTRY            21 non-null object
# DELIVERY_COUNTRY           21 non-null object
# dtypes: int32(5), object(54)
# memory usage: 9.3+ KB
# RUN_ID                     21
# ACTIVE                     21
# ORGANIZATION_CODE          21
# SERVICE_GROUP_CODE          0
# ORDER_STATE                21
# SERVICE_TYPE_CODE           0
# PW                          0
# FULL_TRUCK_TYPE             0
# RELATED_ORDER_CODE         21
# RELATED_ORDER_TYPE         21
# DATE_BOOKING               21
# DATE_LOADING               21
# WH_DELIVERED                0
# DATE_WH_ENTRY              21
# LAST_WH                    21
# DATE_LAST_WH_FINISH        21
# CUSTOMER_COMPANY_CODE       0
# LOADING_COMPANY_CODE        0
# CUSTOMS_COMPANY_CODE        0
# CUSTOMSEE_COMPANY_CODE     21
# DELIVERY_COMPANY_CODE       0
# CUSTOMS_TYPE                0
# POSITION_CODE              21
# POSITION_STATE             21
# RORO_LOAD_CODE             21
# TRAIN_LOAD_CODE            21
# PLATE_NUMBER               21
# FREEZONE                    0
# CARRY_TYPE                  0
# CARRY_RESTRICTION          21
# OG_DELAY                   21
# PREFERRED_MODE             21
# LAST_WH_COMPANY_CODE       21
# SPECIAL_LOAD_TYPE          21
# GATE_COMPANY_CODE          21
# GROSS_WEIGHT                0
# SYSTEM_FULL_TRUCK_TYPE      0
# DEPOT_COMPANY_CODE         21
# PREFERRED_MULT             21
# POS_VH_CATEGORY            21
# DISPOSITION_CODE           21
# FROM_COMPANY_CODE          21
# TO_COMPANY_CODE            21
# DATE_PORT_ARRIVAL          21
# REPLAN                     21
# PRIO_COEF                  21
# LATENESS_EXCEPTION         21
# FORBIDDEN_MODE             21
# ESTIMATED_LOADING_START    21
# IGNORE_DEPOT               21
# UNLOADING_COMPANY_CODE     21
# POSITION_UNLOADING_NO      21
# REVENUE                     0
# DT_RDY_WEEK                 0
# DT_RDY_DAY                  0
# DT_ETA_WEEK                 0
# DT_ETA_DAY                  0
# LOADING_COUNTRY             0
# DELIVERY_COUNTRY            0
# dtype: int64

# %%
num_cols = list(df_x._get_numeric_data().columns)
#print(num_cols)

fix_cols = []
for col in df_x.columns:
    if df_x[col].nunique() == 1:
        fix_cols.append(col)
    else:
        pass

emp_cols = []
for col in df_x.columns:
    if df_x[col].count() > 0:
        pass
    else:
        emp_cols.append(col)


cat_cols = list(set(df_x.columns) - set(num_cols) - set(emp_cols) - set(fix_cols))
num_cols = list(set(num_cols) - set(fix_cols) - set(emp_cols))
#print(df_x[cat_cols])
#print(df_x['GATE_COMPANY_CODE'].value_counts())
#df_x['CUSTOMSEE_COMPANY_CODE'].value_counts()
#customsee float geldiği için .0 var stringinde, sorun yok ama.

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler(copy=True, feature_range=(0, 1))
le = preprocessing.LabelEncoder()
ohe = preprocessing.OneHotEncoder(categories = 'auto')


df_x_new = pd.DataFrame()

map =[]
i = 0
print(df_x[cat_cols].head(3))

for col in cat_cols:
    
    df_x[col] = le.fit_transform(df_x[col].astype(str))
    mappers = dict(zip(le.classes_, le.transform(le.classes_))).copy()
    map_list = list(mappers.keys())
    #inv_mappers = {v: k for k, v in mappers.items()} KEY ile VALUE Yerini değiştiriyor
    #inv_mappers = {int(k):str(v) for k,v in inv_mappers.items()} Key ile value tipini değiştiriyor
    map.append(dict(zip(le.classes_, le.transform(le.classes_))).copy())
        
    if df_x[col].nunique()>1:
        df_r = ohe.fit_transform(df_x[[col]]).toarray()
        df_r_df = pd.DataFrame(df_r, columns = str(i)+'_'+le.classes_)
        #df_r_df = pd.DataFrame(df_r, columns = [str(i)+'_'+le.classes_]) yaptığımda multiindex haline getirdi sütunları
        #df_r_df.columns = df_r_df.columns.astype(str)
        df_x_new = pd.concat([df_x_new, df_r_df], axis=1)
        #print(le.classes_)
        #print(le.transform(le.classes_))
    else:
        
        df_r_df = pd.DataFrame(df_x[col], columns = str(i)+'_'+le.classes_)
        #df_r_df = pd.DataFrame(df_x[col])
        df_x_new = pd.concat([df_x_new, df_r_df], axis=1)
    #print(np.isnan(df_r_df).any()) check null items
    #print(np.isfinite(df_r_df).any()) check infinite items
    
    i = i+1
#!!!!! eğer (XYZ,) şeklinde bir sütun başlığı oluşturuyorsa multiindex yapıyor demektir.
#Bu durumda dataframe içinde columns = [] olmalı columns = ... yerine veya tam tersi


min_max = {}
for col in num_cols:
    min_col = 0
    max_col = 0
    df_x[col] = pd.to_numeric(df_x[col])
    min_col = df_x[col].min()
    max_col = df_x[col].max()
    min_max[str(i)+'_'+col] = [min_col,max_col]
    print(min_max)
    df_s = scaler.fit_transform(df_x[[col]])
    df_s_df = pd.DataFrame(df_s, columns = [str(i)+'_'+col])
    df_s_df.columns = df_s_df.columns.astype(str)
    df_x_new = pd.concat([df_x_new, df_s_df], axis=1)
    i=i+1
    

full_data = pd.concat([df_x_new, df_y], axis = 1)
# Out:
#   DT_ETA_DAY DT_RDY_DAY DT_RDY_WEEK SYSTEM_FULL_TRUCK_TYPE DT_ETA_WEEK
# 0          1          1          40                  FTL-B          41
# 1          4          4          40                  FTL-B          41
# 2          1          1          41                  FTL-B          42
# {'5_GROSS_WEIGHT': [9258, 20853]}
# C:\ProgramData\Anaconda3\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int32 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from sklearn.model_selection import train_test_split

x = np.array(full_data.drop('classification', axis=1))
y = np.array(full_data['classification'])

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 3)


from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt

"""
rmse_val = [] #to store rmse values for different k
for K in range(30):
    K = K+1
    
    model = neighbors.KNeighborsRegressor(n_neighbors = K)
    model.fit(x_train, y_train)  #fit the model
    pred=model.predict(x_test) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)

curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()
"""
# Out:
# "\nrmse_val = [] #to store rmse values for different k\nfor K in range(30):\n    K = K+1\n    \n    model = neighbors.KNeighborsRegressor(n_neighbors = K)\n    model.fit(x_train, y_train)  #fit the model\n    pred=model.predict(x_test) #make prediction on test set\n    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse\n    rmse_val.append(error) #store rmse values\n    print('RMSE value for k= ' , K , 'is:', error)\n\ncurve = pd.DataFrame(rmse_val) #elbow curve \ncurve.plot()\n"

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler()
df_x_new_res, df_y_res = rus.fit_resample(df_x_new, np.ravel(df_y))

"""
from imblearn.under_sampling import InstanceHardnessThreshold
iht = InstanceHardnessThreshold(random_state=35, sampling_strategy = 1)
df_x_new_res, df_y_res = iht.fit_resample(df_x_new, np.ravel(df_y))
"""
"""
from imblearn.under_sampling import NearMiss
nm = NearMiss(random_state = 35, n_neighbors = 10, sampling_strategy = 1, version = 3, n_neighbors_ver3 = 10)
df_x_new_res, df_y_res = nm.fit_resample(df_x_new, np.ravel(df_y))
"""

df_x_new_res = pd.DataFrame(df_x_new_res, columns = df_x_new.columns)
df_y_res = pd.DataFrame(df_y_res, columns = df_y.columns)

# %%
col_prefix=[]
for col in df_x_new.columns:
    #print(col[0:20])
    if col.split("_")[0] in col_prefix:
        pass
    else:
        col_prefix.append(col.split("_")[0])


#print(col_prefix)
#print(df_x_new_res.info())


df_result = pd.DataFrame()
cat = 0
num = 0
for item in col_prefix:
    #print(df_x_new_res[[col for col in df_x_new_res if col.startswith(item+'_')]].head(4))
    df_reverse = pd.DataFrame()
    df_reverse = df_x_new_res[[col for col in df_x_new_res if col.startswith(item+'_')]]
    if len([col for col in df_x_new_res if col.startswith(item+'_')])>1:
        df_reverse = df_reverse.idxmax(1)
        df_reverse = pd.DataFrame(df_reverse,columns = [cat_cols[cat]])
        df_reverse = df_reverse.applymap(lambda x: x.replace(item+'_', ''))
        #df_reverse.columns = cat_cols[cat]
        df_result = pd.concat([df_result, df_reverse], axis = 1)
        #print(df_reverse.head(4))
        #print(cat_cols[cat])
        cat = cat+1
    
    else:
        for col in df_reverse:
            #print(min_max[col][:])
            mn = np.array(min_max[col][:1])
            mx = np.array(min_max[col][1:])
            df_reverse[col] = round(df_reverse[col]*(mx-mn)+mn,0)
            df_result = pd.concat([df_result, df_reverse], axis = 1)
    #print(df_result.head(4))
#df_result.columns = pd.concat([pd.Series(cat_cols), pd.Series(num_cols)], axis=1)       

for col in (fix_cols + emp_cols):
    
    df_result = pd.concat([df_result, df_x[col].iloc[:len(df_y_res)]],axis = 1)
    


df_result = pd.concat([df_result, df_y_res], axis=1)
#print(df_result.head(3))
#print(df_y_res['classification'].value_counts())
#print(df_result.columns)
#print(df_result['DT_RDY_WEEK'].value_counts().plot(kind='bar'))
# Out:
# C:\ProgramData\Anaconda3\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
"""
import matplotlib.pyplot as plt

ax = plt.subplot(3,1,1)
ax.bar(sorted(df_result[df_result['classification']==0]['SERVICE_TYPE_CODE'].unique().astype(str)), \
        df_result[df_result['classification']==0]['SERVICE_TYPE_CODE'].value_counts(normalize =True).sort_index()*100 , \
        width = 0.6, color = 'b', align = 'center')
ax.bar(sorted(df[df['classification']==0]['SERVICE_TYPE_CODE'].unique().astype(str)), \
        df[df['classification']==0]['SERVICE_TYPE_CODE'].value_counts(normalize =True).sort_index()*100, \
        width = 0.2, color = 'g', align = 'center')
ax.autoscale(tight = True)

ax2 = plt.subplot(3,1,2)
ax2.bar(sorted(df_result[df_result['classification']==0]['DT_RDY_WEEK'].unique().astype(str)), \
        df_result[df_result['classification']==0]['DT_RDY_WEEK'].value_counts(normalize =True).sort_index()*100 , \
        width = 0.6, color = 'b', align = 'center')
ax2.bar(sorted(df[df['classification']==0]['DT_RDY_WEEK'].unique().astype(str)), \
        df[df['classification']==0]['DT_RDY_WEEK'].value_counts(normalize =True).sort_index()*100, \
        width = 0.2, color = 'g', align = 'center')
ax2.autoscale(tight = True) #labels do not appear in right order, it is false

ax3 = plt.subplot(3,1,3)
ax3.bar(sorted(df_result[df_result['classification']==0]['DT_RDY_DAY'].unique().astype(str)), \
        df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100 , \
        width = 0.6, color = 'b', align = 'center')
ax3.bar(sorted(df[df['classification']==0]['DT_RDY_DAY'].unique().astype(str)), \
        df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100, \
        width = 0.2, color = 'g', align = 'center')
ax3.autoscale(tight = True)

plt.show()

print(df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =False).sort_index())
print(df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100)
print(df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =False).sort_index())
print(df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100)
"""

#writer = pd.ExcelWriter(r'C:\Users\ali.kilinc\Desktop\NEW DATA\OUTPUT\N34_PYTHON_OUTPUT.xlsx')
#df_result.to_excel(writer,'OUTPUT')
#writer.save()
# Out:
# "\nimport matplotlib.pyplot as plt\n\nax = plt.subplot(3,1,1)\nax.bar(sorted(df_result[df_result['classification']==0]['SERVICE_TYPE_CODE'].unique().astype(str)),         df_result[df_result['classification']==0]['SERVICE_TYPE_CODE'].value_counts(normalize =True).sort_index()*100 ,         width = 0.6, color = 'b', align = 'center')\nax.bar(sorted(df[df['classification']==0]['SERVICE_TYPE_CODE'].unique().astype(str)),         df[df['classification']==0]['SERVICE_TYPE_CODE'].value_counts(normalize =True).sort_index()*100,         width = 0.2, color = 'g', align = 'center')\nax.autoscale(tight = True)\n\nax2 = plt.subplot(3,1,2)\nax2.bar(sorted(df_result[df_result['classification']==0]['DT_RDY_WEEK'].unique().astype(str)),         df_result[df_result['classification']==0]['DT_RDY_WEEK'].value_counts(normalize =True).sort_index()*100 ,         width = 0.6, color = 'b', align = 'center')\nax2.bar(sorted(df[df['classification']==0]['DT_RDY_WEEK'].unique().astype(str)),         df[df['classification']==0]['DT_RDY_WEEK'].value_counts(normalize =True).sort_index()*100,         width = 0.2, color = 'g', align = 'center')\nax2.autoscale(tight = True) #labels do not appear in right order, it is false\n\nax3 = plt.subplot(3,1,3)\nax3.bar(sorted(df_result[df_result['classification']==0]['DT_RDY_DAY'].unique().astype(str)),         df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100 ,         width = 0.6, color = 'b', align = 'center')\nax3.bar(sorted(df[df['classification']==0]['DT_RDY_DAY'].unique().astype(str)),         df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100,         width = 0.2, color = 'g', align = 'center')\nax3.autoscale(tight = True)\n\nplt.show()\n\nprint(df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =False).sort_index())\nprint(df_result[df_result['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100)\nprint(df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =False).sort_index())\nprint(df[df['classification']==0]['DT_RDY_DAY'].value_counts(normalize =True).sort_index()*100)\n"
